# %%
import pandas as pd

df = pd.read_csv("../data/sample.csv")

print("Shape:", df.shape)
print("\nHead:")
print(df.head())

print("\nDescribe:")
print(df.describe())
# Out:
# Shape: (5, 3)
#
# Head:
#      name  age  score
# 0     Ali   22     85
# 1    Sara   24     90
# 2    Omar   21     70
# 3    Lina   23     95
# 4  Hassan   25     60
#
# Describe:
#              age     score
# count   5.000000   5.00000
# mean   23.000000  80.00000
# std     1.581139  14.57738
# min    21.000000  60.00000
# 25%    22.000000  70.00000
# 50%    23.000000  85.00000
# 75%    24.000000  90.00000
# max    25.000000  95.00000
